# %% [markdown]
# ## 🧬 LLM × Evolutionary Algorithms
#
# ### Learning objectives
# - Call an LLM (Gemini) from Python and parse the code it returns.
# - Use an LLM to generate metaheuristics and benchmark them on a standard test function.
# - Iterate on those algorithms with simple evolutionary operators.
#
# ### 1. Environment setup
# - Sign in to [Google AI Studio](https://aistudio.google.com/api-keys) and generate an API key.
# - We use Gemini for its generous free tier (~1500 requests/day).

# %%
# ! pip install google-genai

# %%
import copy

# %%
from google import genai

MODEL = "gemini-2.5-flash"
client = genai.Client(api_key="X")

# Smoke test
print(client.models.generate_content(model=MODEL, contents=["Hello, world!"]).text)
# Out:
# Hello back! 👋
#
# A classic greeting. How can I assist you today?

# %% [markdown]
# ### 2. Generating metaheuristics with an LLM
#
# LLMs can write Python, so we can ask them to write *optimization algorithms*. The workflow is simple: prompt the model with a function signature, parse the code from its response, and run it on a benchmark.
#
# We'll need a small utility to extract a function from a Markdown code block, validate it, and load it into the current namespace:

# %%
import ast
import re
from typing import Any, Callable


class FunctionParser:
    """Extracts a Python function from an LLM response and loads it as a callable.

    LLMs typically return code wrapped in a Markdown ```python ... ``` block,
    often surrounded by explanatory prose. This helper isolates the code,
    checks it parses as valid Python, executes it in a fresh namespace, and
    returns the named function so it can be called like any other callable.
    """

    @staticmethod
    def parse(model_response: str, function_name: str) -> Callable | None:
        """Parse `model_response` and return the function named `function_name`.

        Returns None if no code block is found or if the code is syntactically
        invalid. Otherwise the extracted code is executed and the requested
        function is looked up in the resulting namespace.
        """
        function_str = FunctionParser.extract_code(model_response)
        if not function_str or not FunctionParser.validate_function_syntax(function_str):
            return None
        namespace: dict[str, Any] = {}
        # WARNING: exec runs arbitrary model output. In production this MUST
        # happen inside a sandbox (subprocess, container, restricted runtime).
        exec(function_str, namespace)
        if function_name in namespace:
            return namespace[function_name]
        candidate_names = FunctionParser.list_function_names(function_str)
        if len(candidate_names) == 1 and candidate_names[0] in namespace:
            return namespace[candidate_names[0]]
        raise KeyError(f"Function '{function_name}' not found. Available: {candidate_names}")

    @staticmethod
    def list_function_names(function_str: str) -> list[str]:
        """Return top-level function names from code string."""
        tree = ast.parse(function_str)
        return [node.name for node in tree.body if isinstance(node, ast.FunctionDef)]

    @staticmethod
    def validate_function_syntax(function_str: str) -> bool:
        """Return True iff `function_str` parses as valid Python (AST check only).

        This catches malformed code before we exec it, but does not guarantee
        the code is safe or semantically correct.
        """
        try:
            ast.parse(function_str)
            return True
        except SyntaxError:
            return False

    @staticmethod
    def extract_code(text: str) -> str | None:
        """Pull the first fenced code block or def block out of an LLM response.

        Returns the inner code as a string, or None if no suitable block
        is present.
        """
        fenced_match = re.search(r"```(?:python)?\s*(.*?)\s*```", text, re.DOTALL | re.IGNORECASE)
        if fenced_match:
            return fenced_match.group(1)
        def_match = re.search(r"(def\s+\w+\s*\(.*)", text, re.DOTALL)
        return def_match.group(1) if def_match else None

# %% [markdown]
# Now ask the LLM to invent a metaheuristic. We pin the function signature so the response is directly executable:

# %%
PROMPT_METAHEURISTIC = """
Problem: You are tasked with inventing a novel metaheuristic algorithm capable of minimizing an arbitrary real-valued,
black-box, single-objective function defined over simple bound constraints.

Write a Python function that implements your algorithm. The function must take exactly these arguments:
- function: Callable[np.ndarray], float] - the objective function to minimise.
- bounds: list[tuple[float, float]] - a list of (lower, upper) pairs delimiting the search space for each dimension.
- budget: int - the total number of objective-function evaluations the algorithm may perform.

The function should return a tuple[float, np.ndarray] containing the best objective value found and the corresponding decision vector.

Your solution should be wrapped in a Markdown Python code block.

```python
import numpy as np

def new_metaheuristic(
	function: Callable[[np.ndarray], float],
    bounds: list[tuple[float, float]],
    budget: int
) -> tuple[float, np.ndarray]:
    ...
```
"""

response = client.models.generate_content(model=MODEL, contents=[PROMPT_METAHEURISTIC])
print(response.text)
# Out:
# The metaheuristic algorithm invented here is called "Adaptive Information Diffusion (AID)". It is inspired by the principles of swarm intelligence and the idea of "information diffusion" through a network of agents. Each agent (particle) in the swarm not only learns from its own past best performance and the global best performance of the swarm (similar to Particle Swarm Optimization) but also receives a directional "pull" from its better-performing neighbors. This "diffusion vector" guides the particle towards regions where nearby solutions have found lower objective values, promoting local exploitation in promising areas identified by the neighborhood. Random exploration is also incorporated to prevent premature convergence and encourage diversity.
#
# Here's a breakdown of the AID algorithm:
#
# 1.  **Initialization**:
#     *   A population of `N` particles is randomly initialized within the given `bounds`.
#     *   Each particle's current position and its objective value are stored.
#     *   Each particle keeps track of its `personal_best_position` and `personal_best_value`.
#     *   The `global_best_position` and `global_best_value` found across the entire swarm are maintained.
#     *   The initial `N` evaluations contribute to the total `budget`.
#
# 2.  **Main Loop (Iterations)**:
#     *   The algorithm iterates until the `budget` of function evaluations is exhausted.
#     *   In each iteration, for every particle `i`:
#         *   **Neighborhood Information Gathering**:
#             *   The `K` nearest neighbors to particle `i` (in the decision space) are identified.
#             *   A `diffusion_vec` is calculated by summing the vectors pointing from `current_pos` to each neighbor `j` *only if* neighbor `j` has a better objective value than particle `i`.
#             *   This `diffusion_vec` is then normalized to represent a pure direction.
#         *   **Position Update**: Particle `i`'s new position is determined by summing four components:
#             *   **Diffusion Component**: A movement in the direction of the `diffusion_vec`, scaled by `c_diffusion` and the overall `search_space_range`. This encourages particles to move towards local pockets of improvement.
#             *   **Global Best Component**: A pull towards the `global_best_position`, scaled by `c_global` and a random factor `r1`. This promotes global exploitation.
#             *   **Personal Best Component**: A pull towards its own `personal_best_position`, scaled by `c_personal` and a random factor `r2`. This helps particles to revisit historically good locations.
#             *   **Exploration Component**: A random step (Gaussian noise) scaled by `c_exploration` and the `search_space_range`. This aids in exploring new regions and escaping local optima.
#         *   **Boundary Handling**: The `new_pos` is clipped to ensure it stays within the specified `bounds`.
#         *   **Evaluation and Update**: The objective `function` is evaluated at `new_pos`.
#             *   `personal_best` and `global_best` values are updated if a better solution is found.
#             *   The particle's `current_pos` and `current_value` are updated for the next iteration.
#
# 3.  **Termination**: The loop terminates when the `eval_count` reaches the specified `budget`.
#
# 4.  **Return Value**: The `global_best_value` found and its corresponding `global_best_position`.
#
# **Novelty**: The core novelty lies in the "diffusion vector" that explicitly aggregates directional influence from *only better-performing neighbors*. This is distinct from standard PSO's velocity update (which often considers a general neighborhood best or a fixed topology) or other local search mechanisms, by directly summing improvement vectors from local, superior "information sources" and normalizing them to provide a directed, scaled move.
#
# ```python
# import numpy as np
# from typing import Callable, List, Tuple
#
# def new_metaheuristic(
#     function: Callable[[np.ndarray], float],
#     bounds: List[Tuple[float, float]],
#     budget: int
# ) -> Tuple[float, np.ndarray]:
#     """
#     Implements the Adaptive Information Diffusion (AID) metaheuristic algorithm
#     to minimize a black-box, single-objective function within bound constraints.
#
#     Args:
#         function: The objective function to minimize. It takes a np.ndarray
#                   (decision vector) and returns a float (objective value).
#         bounds: A list of (lower, upper) pairs defining the search space for
#                 each dimension.
#         budget: The total number of objective-function evaluations allowed.
#
#     Returns:
#         A tuple containing:
#             - The best objective value found (float).
#             - The corresponding decision vector (np.ndarray).
#     """
#
#     D = len(bounds) # Number of dimensions
#
#     # Handle edge cases for budget
#     if budget <= 0:
#         return float('inf'), np.zeros(D) # No evaluations possible, return dummy values
#
#     lower_bounds = np.array([b[0] for b in bounds])
#     upper_bounds = np.array([b[1] for b in bounds])
#     search_space_range = upper_bounds - lower_bounds
#
#     # --- Parameters for AID Algorithm ---
#     # Population size (N)
#     # N is dynamically set to balance exploration/exploitation, considering budget and dimensions.
#     # It must be at least 2 for neighbor finding, and capped to prevent excessive initial evaluations.
#     N = max(2, min(50, budget // 2 if budget > 10 else budget))
#     if N > budget: N = budget # Ensure population size doesn't exceed budget for initial evaluations
#
#     # Special case for extremely small budgets where N=1 is the only option.
#     # This simplifies the logic by handling single-point sampling directly.
#     if N == 1:
#         initial_pos = lower_bounds + np.random.rand(D) * search_space_range
#         best_val = function(initial_pos)
#         return best_val, initial_pos
#
#     K_neighbors = max(1, min(N - 1, int(0.1 * N))) # Number of nearest neighbors to consider (min 1, max N-1)
#
#     # Coefficients for the different components of particle movement (can be tuned)
#     c_diffusion = 0.5   # Weight for diffusion towards better neighbors
#     c_global = 1.5      # Weight for attraction to the global best position
#     c_personal = 1.5    # Weight for attraction to the particle's own personal best position
#     c_exploration = 0.1 # Weight for random exploration noise
#
#     # --- Initialization ---
#     population = np.zeros((N, D))          # Current positions of all particles
#     population_values = np.full(N, float('inf')) # Current objective values of all particles
#
#     personal_best_positions = np.zeros((N, D)) # Personal best positions for each particle
#     personal_best_values = np.full(N, float('inf')) # Personal best values for each particle
#
#     global_best_position = np.zeros(D)  # Global best position found so far
#     global_best_value = float('inf')    # Global best objective value found so far
#
#     eval_count = 0 # Counter for objective function evaluations
#
#     # Generate initial population randomly within bounds and evaluate
#     for i in range(N):
#         population[i] = lower_bounds + np.random.rand(D) * search_space_range
#         val = function(population[i])
#         eval_count += 1
#         population_values[i] = val # Store current value
#
#         # Update personal best for particle i
#         if val < personal_best_values[i]:
#             personal_best_values[i] = val
#             personal_best_positions[i] = population[i].copy()
#
#         # Update global best if a new best is found
#         if val < global_best_value:
#             global_best_value = val
#             global_best_position = population[i].copy()
#
#         # Check budget after each evaluation
#         if eval_count >= budget:
#             return global_best_value, global_best_position
#
#     # --- Main Optimization Loop (Iterations) ---
#     while eval_count < budget:
#         for i in range(N):
#             # Check budget again before processing each particle
#             if eval_count >= budget:
#                 break
#
#             current_pos = population[i]
#             current_val = population_values[i]
#
#             # 1. Neighborhood Information Gathering (Diffusion)
#             # Calculate Euclidean distances from current_pos to all other particles
#             distances = np.linalg.norm(population - current_pos, axis=1)
#             distances[i] = float('inf') # Exclude the particle itself from its neighbors
#
#             # Identify K_neighbors nearest neighbors
#             nearest_neighbor_indices = np.argsort(distances)[:K_neighbors]
#
#             diffusion_vec = np.zeros(D)
#             num_better_neighbors = 0
#             for neighbor_idx in nearest_neighbor_indices:
#                 neighbor_pos = population[neighbor_idx]
#                 neighbor_val = population_values[neighbor_idx]
#
#                 # Only consider neighbors that are "better" (have a lower objective value)
#                 if neighbor_val < current_val:
#                     diffusion_vec += (neighbor_pos - current_pos) # Sum vectors towards better neighbors
#                     num_better_neighbors += 1
#
#             # Normalize diffusion_vec if there are better neighbors to get a pure direction
#             if num_better_neighbors > 0:
#                 diffusion_vec_magnitude = np.linalg.norm(diffusion_vec)
#                 if diffusion_vec_magnitude > 1e-9: # Avoid division by zero for very small sums
#                     diffusion_vec = diffusion_vec / diffusion_vec_magnitude
#                 else:
#                     diffusion_vec = np.zeros(D) # If sum of vectors results in a zero vector
#             else:
#                 diffusion_vec = np.zeros(D) # No better neighbors in the vicinity to diffuse from
#
#             # 2. Position Update Components
#             # Generate random factors for stochasticity, similar to r1, r2 in PSO
#             r1 = np.random.rand(D) # Random vector for global best attraction
#             r2 = np.random.rand(D) # Random vector for personal best attraction
#
#             # Diffusion component: scaled by coefficient and overall search space range
#             diffusion_component = c_diffusion * diffusion_vec * search_space_range
#
#             # Global best component: attraction towards the best position found by the swarm
#             global_best_component = c_global * r1 * (global_best_position - current_pos)
#
#             # Personal best component: attraction towards the particle's own best position
#             personal_best_component = c_personal * r2 * (personal_best_positions[i] - current_pos)
#
#             # Exploration noise component: adds random perturbation, scaled by search space range
#             exploration_component = c_exploration * np.random.randn(D) * search_space_range
#
#             # Sum all components to calculate the new potential position
#             new_pos = current_pos + diffusion_component + global_best_component + personal_best_component + exploration_component
#
#             # Apply bounds: Clip the new position to ensure it stays within the search space
#             new_pos = np.clip(new_pos, lower_bounds, upper_bounds)
#
#             # Evaluate the new position
#             new_val = function(new_pos)
#             eval_count += 1
#
#             # Update personal best if the new position is better
#             if new_val < personal_best_values[i]:
#                 personal_best_values[i] = new_val
#                 personal_best_positions[i] = new_pos.copy()
#
#             # Update global best if the new position is the best found so far
#             if new_val < global_best_value:
#                 global_best_value = new_val
#                 global_best_position = new_pos.copy()
#
#             # Update the particle's current position and its objective value
#             population[i] = new_pos.copy()
#             population_values[i] = new_val
#
#     # Return the best value and position found after exhausting the budget
#     return global_best_value, global_best_position
# ```

# %% [markdown]
# Parse it and benchmark on Rastrigin (10D, average over 10 seeds):

# %%
import random
from typing import Callable

import numpy as np


def rastrigin(x: np.ndarray) -> float:
    A: float = 10.0
    return float(A * len(x) + np.sum(x**2 - A * np.cos(2 * np.pi * x)))


class OptimizerVerifier:
    def __init__(
        self,
        budget: int = 10_000,
        dims: int = 10,
        seeds_count: int = 10,
        test_function: Callable = rastrigin,
    ) -> None:
        self.budget = budget
        self.dims = dims
        self.seeds_count = seeds_count
        self.test_function = test_function

    def verify(self, optimizer: Callable) -> float:
        bounds = [(-5, 5) for _ in range(self.dims)]
        results = []
        for seed in range(self.seeds_count):
            np.random.seed(seed)
            random.seed(seed)
            best_val, _ = optimizer(self.test_function, bounds, self.budget)
            results.append(best_val)
        return float(np.mean(results))


metaheuristic = FunctionParser.parse(response.text, "new_metaheuristic")
mean_score_for_rastrigin = OptimizerVerifier().verify(metaheuristic)
mean_score_for_rastrigin
# Out:
# 59.55682106685066

# %% [markdown]
# ### 3. Evolution of Heuristics
#
# Each generated metaheuristic has a measurable fitness (its score on the benchmark). That means we can apply crossover and mutation operators to *textual* solutions and run an evolutionary loop in the space of Python functions that represent optimization algorithms.
#
# ### Exercise 1
# Describe the meta‑heuristic generated by Gemini. Does the idea make sense? Is it novel? What are its weaknesses?

# %% [markdown]
# Algorytm symuluje rozprzestrzenianie się wpływu społecznego w sieci. Każdy agent (kandydatury rozwiązanie) ma "wpływ" odwrotnie proporcjonalny do wartości funkcji celu - im lepsze rozwiązanie, tym większy wpływ na innych. Agenci poruszają się w kierunku lepszych sąsiadów. Algorytm sam w sobie nie jest nowatorski, chociaż, co na plus, łączy w sobie kilka znanych metaheurystyk, np. wpływ jako odwrotność fitness (PSO), czy różne składowe, wpływające na ruch w danym kroku (np. przyciąganie w kierunku najlepszego globalnego osobnika, najlepsze sąsiada itd). Dla funkcji Rastrigina zwrócił średnią wartość 36.54, zatem dość słabo - nie zszedł dokładnie w dołek, zbyt mała liczba iteracji ($y=0$).

# %% [markdown]
# > Wyniki u góry różnią się od opisu algorytmu, ze względu na ponowne wywołanie komórek. Opisuję, to co wyszło pierwotnie.

# %% [markdown]
# ### Exercise 2
# Generate N = 5 distinct algorithms, benchmark them, and report the best.
#
# > **💡 Tip.** The underlying idea is simple: instead of trying to produce a single perfect algorithm, use the LLM as a generator that samples many different approaches. In practice, we could generate thousands of candidate algorithms and automatically evaluate them. Most of them will likely be poor, but that is acceptable — we only need a few strong candidates to discover an effective baseline. The key insight is that the LLM is valuable not just as a solver, but as a high-throughput source of diverse algorithmic ideas.

# %%
import time

scores = []
for i in range(5):
    response_temp = client.models.generate_content(model=MODEL, contents=[PROMPT_METAHEURISTIC])
    metaheuristic = FunctionParser.parse(response_temp.text, "new_metaheuristic")

    score = OptimizerVerifier().verify(metaheuristic)
    scores.append(score)
    print(f"[{i+1}/5] Score: {score:.4f}\n")
    time.sleep(5)

print(f"Mean: {np.mean(scores):.4f}, Std: {np.std(scores):.4f}")
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[62], line 5
#       1 import time
#       2
#       3 scores = []
#       4 for i in range(5):
# ----> 5     response_temp = client.models.generate_content(model=MODEL, contents=[PROMPT_METAHEURISTIC])
#       6     metaheuristic = FunctionParser.parse(response_temp.text, "new_metaheuristic")
#       7
#       8     score = OptimizerVerifier().verify(metaheuristic)
#
# File c:\Users\Filip\Desktop\UMISI\Stochastic-Methods-in-Machine-Learning\11-model\.venv\Lib\site-packages\google\genai\models.py:6287, in Models.generate_content(self, model, contents, config)
#    6285 while remaining_remote_calls_afc > 0:
#    6286   i += 1
# -> 6287   response = self._generate_content(
#    6288       model=model, contents=contents, config=parsed_config
#    6289   )
#    6291   function_map = _extra_utils.get_function_map(parsed_config)
#    6292   if not function_map:
#
# File c:\Users\Filip\Desktop\UMISI\Stochastic-Methods-in-Machine-Learning\11-model\.venv\Lib\site-packages\google\genai\models.py:4723, in Models._generate_content(self, model, contents, config)
#    4720 request_dict = _common.convert_to_dict(request_dict)
#    4721 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4723 response = self._api_client.request(
#    4724     'post', path, request_dict, http_options
#    4725 )
#    4727 if config is not None and getattr(
#    4728     config, 'should_return_http_response', None
#    4729 ):
#    4730   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\Users\Filip\Desktop\UMISI\Stochastic-Methods-in-Machine-Learning\11-model\.venv\Lib\site-packages\google\genai\_api_client.py:1609, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1599 def request(
#    1600     self,
#    1601     http_method: str,
#    (...)   1604     http_options: Optional[HttpOptionsOrDict] = None,
#    1605 ) -> SdkHttpResponse:
#    1606   http_request = self._build_request(
#    1607       http_method, path, request_dict, http_options
#    1608   )
# -> 1609   response = self._request(http_request, http_options, stream=False)
#    1610   response_body = (
#    1611       response.response_stream[0] if response.response_stream else ''
#    1612   )
#    1613   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\Filip\Desktop\UMISI\Stochastic-Methods-in-Machine-Learning\11-model\.venv\Lib\site-packages\google\genai\_api_client.py:1402, in BaseApiClient._request(self, http_request, http_options, stream)
#    1399     retry = tenacity.Retrying(**retry_kwargs)
#    1400     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1402 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\Filip\Desktop\UMISI\Stochastic-Methods-in-Machine-Learning\11-model\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File c:\Users\Filip\Desktop\UMISI\Stochastic-Methods-in-Machine-Learning\11-model\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\Filip\Desktop\UMISI\Stochastic-Methods-in-Machine-Learning\11-model\.venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\Users\Filip\Desktop\UMISI\Stochastic-Methods-in-Machine-Learning\11-model\.venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File C:\Program Files\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Program Files\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\Filip\Desktop\UMISI\Stochastic-Methods-in-Machine-Learning\11-model\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\Filip\Desktop\UMISI\Stochastic-Methods-in-Machine-Learning\11-model\.venv\Lib\site-packages\google\genai\_api_client.py:1379, in BaseApiClient._request_once(self, http_request, stream)
#    1371   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1372       method=http_request.method,
#    1373       url=http_request.url,
#    (...)   1376       timeout=http_request.timeout,
#    1377   )
#    1378   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1379 errors.APIError.raise_for_response(response)
#    1380 return HttpResponse(
#    1381     response.headers, response if stream else [response.text]
#    1382 )
#
# File c:\Users\Filip\Desktop\UMISI\Stochastic-Methods-in-Machine-Learning\11-model\.venv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     152 else:
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\Filip\Desktop\UMISI\Stochastic-Methods-in-Machine-Learning\11-model\.venv\Lib\site-packages\google\genai\errors.py:186, in APIError.raise_error(cls, status_code, response_json, response)
#     184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
# --> 186   raise ServerError(status_code, response_json, response)
#     187 else:
#     188   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}

# %% [markdown]
# ### Exercise 3
# Review [Evolution of Heuristics: Towards Efficient Automatic Algorithm Design Using Large Language Model](https://arxiv.org/pdf/2401.02051) and read **3.4 Prompt Strategies**. Re-implement one of the prompt strategies (M1, M2, or M3). For reference, here's the [GitHub repository](https://github.com/FeiLiu36/EoH) and here's the key [file](https://github.com/FeiLiu36/EoH/blob/main/eoh/src/eoh/methods/eoh/eoh_evolution.py) with all prompts.

# %% [markdown]
# <details><summary><b>Hint 1</b></summary><br>Read <code>get_prompt_m2</code> method and adapt it to our case (signature of the function is slightly different, but the idea is the same).</details>
#
#
# <details><summary><b>Hint 2</b></summary><br>The core idea behind M2 is: "Please identify the main algorithm parameters and assist me in creating a new algorithm with different parameter settings for the provided score function." We should incorporate this instruction directly into the prompt together with the generated metaheuristic.</details>
#
#
# <details><summary><b>Comment</b></summary><br>In the paper they describe it as "M2: Modify the parameters of one selected heuristic. First, one heuristic is selected from the current population. Then, LLM is prompted to try different parameters in the current heuristic instead of designing a new one." In practice, though, the idea is extremely simple.</details>
#
#
# <details><summary><b>Hint 3</b></summary><br>Use a prompt like this:<pre>I have one algorithm with its code as follows.
# ```python
# {metaheuristic}
# ```
# Please identify the main algorithm parameters and assist me in creating a new algorithm that has a different parameter settings.
# Write a Python function that implements your algorithm. The function must take exactly these arguments:
# - function: Callable[np.ndarray], float] - the objective function to minimise.
# - bounds: list[tuple[float, float]] - a list of (lower, upper) pairs delimiting the search space for each dimension.
# - budget: int - the total number of objective-function evaluations the algorithm may perform.
# The function should return a tuple[float, np.ndarray] containing the best objective value found and the corresponding decision vector.
# Your solution should be wrapped in a Markdown Python code block.
# ```python
# import numpy as np
# def new_metaheuristic(
#     function: Callable[[np.ndarray], float],
#     bounds: list[tuple[float, float]],
#     budget: int
# ) -> tuple[float, np.ndarray]:
#     ...
# ```
# Do not give additional explanations.</pre></details>

# %%
def get_prompt_m2(metaheuristic_code: str) -> str:
    return f"""I have one algorithm with its code as follows.
```python
{metaheuristic_code}
```
Please identify the main algorithm parameters and assist me in creating a new algorithm that has a different parameter settings.
Write a Python function that implements your algorithm. The function must take exactly these arguments:
- function: Callable[np.ndarray], float] - the objective function to minimise.
- bounds: list[tuple[float, float]] - a list of (lower, upper) pairs delimiting the search space for each dimension.
- budget: int - the total number of objective-function evaluations the algorithm may perform.
The function should return a tuple[float, np.ndarray] containing the best objective value found and the corresponding decision vector.
Your solution should be wrapped in a Markdown Python code block.
```python
import numpy as np
def new_metaheuristic(
    function: Callable[[np.ndarray], float],
    bounds: list[tuple[float, float]],
    budget: int
) -> tuple[float, np.ndarray]:
    ...
```
Do not give additional explanations."""

# %% [markdown]
# Is the mutated algorithm better than the original one? How different is it from the original? Experiment with modifying the prompt and observe how the generated algorithm changes. Can you obtain a significant improvement over the original metaheuristic?

# %%
metaheuristic_code = FunctionParser.extract_code(response.text)
prompt = get_prompt_m2(metaheuristic_code)

mutated_response = client.models.generate_content(model=MODEL, contents=[prompt])
mutated_metaheuristic = FunctionParser.parse(mutated_response.text, "new_metaheuristic")

mean_score_for_rastrigin = OptimizerVerifier().verify(mutated_metaheuristic)
mean_score_for_rastrigin

# %% [markdown]
# ### Exercise 4:
# Implement Evolution of Heuristics (or at least part of it). Start simple (pseudocode):
# ```
# current_population = [generate_heuristic()]
# for _ in range(10):
#    parent = current_population[-1]
#    new_solution = M2(parent)
#    f_new_solution = verify(new_solution)
#    current_population.append(new_solution)
# ```
# Save all generated solutions, preferably using a separate file for each one. Analyse the generated algorithms and identify the most common ideas or design patterns. Plot the solution quality across epochs and investigate whether the iterative process exhibits convergence.

# %%
import os
import matplotlib.pyplot as plt

os.makedirs("solutions", exist_ok=True)

# Generate initial heuristic
init_response = client.models.generate_content(model=MODEL, contents=[PROMPT_METAHEURISTIC])
init_code = FunctionParser.extract_code(init_response.text)
init_metaheuristic = FunctionParser.parse(init_response.text, "new_metaheuristic")
init_score = OptimizerVerifier().verify(init_metaheuristic)

with open("solutions/solution_0.py", "w") as f:
    f.write(init_code)

current_population = [(init_metaheuristic, init_code, init_score)]
scores = [init_score]
print(f"[0] Initial score: {init_score:.4f}")

for i in range(10):
    _, parent_code, _ = current_population[-1]

    prompt = get_prompt_m2(parent_code)
    resp = client.models.generate_content(model=MODEL, contents=[prompt])

    new_code = FunctionParser.extract_code(resp.text)
    new_metaheuristic = FunctionParser.parse(resp.text, "new_metaheuristic")

    if new_metaheuristic is None:
        print(f"[{i+1}] Parse failed, reusing parent")
        current_population.append(current_population[-1])
        scores.append(scores[-1])
        continue

    new_score = OptimizerVerifier().verify(new_metaheuristic)

    with open(f"solutions/solution_{i+1}.py", "w") as f:
        f.write(new_code)

    current_population.append((new_metaheuristic, new_code, new_score))
    scores.append(new_score)
    print(f"[{i+1}] Score: {new_score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 7
#       4 os.makedirs("solutions", exist_ok=True)
#       6 # Generate initial heuristic
# ----> 7 init_response = client.models.generate_content(model=MODEL, contents=[PROMPT_METAHEURISTIC])
#       8 init_code = FunctionParser.extract_code(init_response.text)
#       9 init_metaheuristic = FunctionParser.parse(init_response.text, "new_metaheuristic")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\genai\models.py:6495, in Models.generate_content(self, model, contents, config)
#    6493 while remaining_remote_calls_afc > 0:
#    6494   i += 1
# -> 6495   response = self._generate_content(
#    6496       model=model, contents=contents, config=parsed_config
#    6497   )
#    6499   function_map = _extra_utils.get_function_map(parsed_config)
#    6500   if not function_map:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\genai\models.py:4931, in Models._generate_content(self, model, contents, config)
#    4928 request_dict = _common.convert_to_dict(request_dict)
#    4929 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4931 response = self._api_client.request(
#    4932     'post', path, request_dict, http_options
#    4933 )
#    4935 if config is not None and getattr(
#    4936     config, 'should_return_http_response', None
#    4937 ):
#    4938   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\genai\_api_client.py:1611, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1601 def request(
#    1602     self,
#    1603     http_method: str,
#    (...)
#    1606     http_options: Optional[HttpOptionsOrDict] = None,
#    1607 ) -> SdkHttpResponse:
#    1608   http_request = self._build_request(
#    1609       http_method, path, request_dict, http_options
#    1610   )
# -> 1611   response = self._request(http_request, http_options, stream=False)
#    1612   response_body = (
#    1613       response.response_stream[0] if response.response_stream else ''
#    1614   )
#    1615   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\genai\_api_client.py:1404, in BaseApiClient._request(self, http_request, http_options, stream)
#    1401     retry = tenacity.Retrying(**retry_kwargs)
#    1402     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1404 return self._retry(self._request_once, http_request, stream)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File c:\Program Files\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Program Files\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\genai\_api_client.py:1380, in BaseApiClient._request_once(self, http_request, stream)
#    1372 else:
#    1373   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1374       method=http_request.method,
#    1375       url=http_request.url,
#    (...)
#    1378       timeout=http_request.timeout,
#    1379   )
# -> 1380   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
#    1381 errors.APIError.raise_for_response(response)
#    1382 return HttpResponse(
#    1383     response.headers, response if stream else [response.text]
#    1384 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File c:\Program Files\Python312\Lib\ssl.py:1233, in SSLSocket.recv(self, buflen, flags)
#    1229     if flags != 0:
#    1230         raise ValueError(
#    1231             "non-zero flags not allowed in calls to recv() on %s" %
#    1232             self.__class__)
# -> 1233     return self.read(buflen)
#    1234 else:
#    1235     return super().recv(buflen, flags)
#
# File c:\Program Files\Python312\Lib\ssl.py:1106, in SSLSocket.read(self, len, buffer)
#    1104         return self._sslobj.read(len, buffer)
#    1105     else:
# -> 1106         return self._sslobj.read(len)
#    1107 except SSLError as x:
#    1108     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10, 4))
plt.plot(scores, marker="o")
plt.xlabel("Epoch")
plt.ylabel("Mean Rastrigin score (lower is better)")
plt.title("Evolution of Heuristics — M2 mutation")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Recommended Reading
# - [AlphaEvolve: A Gemini-powered coding agent for designing advanced algorithms](https://deepmind.google/discover/blog/alphaevolve-a-gemini-powered-coding-agent-for-designing-advanced-algorithms/)
# - Shojaee, Parshin, et al. [LLM-SR: Scientific equation discovery via programming with large language models.](https://arxiv.org/abs/2404.18400)
# - Romera-Paredes, Bernardino, et al. [Mathematical discoveries from program search with large language models.](https://www.nature.com/articles/s41586-023-06924-6)
# - van Stein, Niki, and Thomas Bäck. [Llamea: A large language model evolutionary algorithm for automatically generating metaheuristics.](https://arxiv.org/abs/2405.20132)
# - Liu, Fei, et al. [Evolution of heuristics: Towards efficient automatic algorithm design using large language model.](https://arxiv.org/abs/2401.02051)
# - van Stein, Niki, et al. [BLADE: Benchmark suite for LLM-driven Automated Design and Evolution of iterative optimisation heuristics](https://arxiv.org/html/2504.20183v1)
# - [OpenEvolve](https://github.com/codelion/openevolve)
